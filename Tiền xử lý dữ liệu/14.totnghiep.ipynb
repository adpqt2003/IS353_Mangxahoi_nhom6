# %% [markdown]
# # Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Đọc & xử lý dữ liệu

# %%
data_path = '/content/drive/MyDrive/Data/Data_clean/EDA'

# %%
# Load dữ liệu
df = pd.read_excel(data_path + '/14.totnghiep_EDA.xlsx')

# %%
# Bỏ các ký tự đặc biệt, chữ thường, xóa khoảng trắng
excute_column = ['mssv']
for column  in df.select_dtypes(include=['object']).columns:
  if column not in excute_column:
    df[column] = df[column].str.lower().str.replace(r"[',:);*@$/%]", '', regex=True)

# %% [markdown]
# # Kiểm tra dữ liệu bị khuyết

# %%
# Đếm số lượng giá trị bị khuyết cho từng cột
missing_values = df.isnull().sum()
missing_values
# Out:
# mssv       2
# xeploai    2
# dtype: int64

# %%
# Tỷ lệ giá trị thiếu
missing_percentage = (df.isnull().mean() * 100).sort_values(ascending=False)
print("Tỷ lệ giá trị thiếu (%):")
print(missing_percentage)
# Out:
# Tỷ lệ giá trị thiếu (%):
# mssv       0.108284
# xeploai    0.108284
# dtype: float64

# %%
# Kiểm tra số dòng chứa giá trị null
num_null_rows = df.isnull().any(axis=1).sum()
print(f"Số dòng chứa giá trị null: {num_null_rows}")
# Out:
# Số dòng chứa giá trị null: 2

# %%
# Lọc các dòng có chứa giá trị null
rows_with_null = df[df.isnull().any(axis=1)]
print(rows_with_null)
# Out:
#      mssv xeploai
# 852   NaN     NaN
# 1708  NaN     NaN

# %% [markdown]
# # Xử lý dữ liệu

# %% [markdown]
# ### Cột mssv

# %%
# kiểm tra dữ liệu khuyết
missing_count = df['mssv'].isnull().sum()
print(f"Số lượng dữ liệu khuyết trong cột 'mssv': {missing_count}")
# Out:
# Số lượng dữ liệu khuyết trong cột 'mssv': 2

# %%
# Loại bỏ các cột bị khuyết
df.dropna(subset=['mssv'], inplace=True)

# %% [markdown]
# ### cột xeploai

# %%
# Số lượng dữ liệu khuyết
missing_count = df['xeploai'].isnull().sum()
print(f"Số lượng dữ liệu khuyết trong cột 'xeploai': {missing_count}")
# Out:
# Số lượng dữ liệu khuyết trong cột 'xeploai': 0

# %%
# Các giá trị duy nhất và tần suất trong cột xeploai
print(f"\nGiá trị duy nhất trong cột 'xeploai':")
print(df['xeploai'].value_counts())
print(df['xeploai'].unique())
# Out:
# Giá trị duy nhất trong cột 'xeploai':
# xeploai
# khá               1125
# giỏi               447
# trung bình khá     172
# tb khá              94
# xuất sắc             7
# Name: count, dtype: int64
# [' khá' ' giỏi' ' trung bình khá' ' xuất sắc' ' tb khá']

# %%
# Bỏ khoảng trắng và viết thường trong các xeploai
df['xeploai'] = df['xeploai'].str.replace(" ", "").str.lower().str.strip()

# %% [markdown]
# ### Lưu dữ liệu đã làm sạch

# %%
df.to_excel("/content/drive/MyDrive/Data/Data_clean/14.totnghiep.xlsx", index=False)
