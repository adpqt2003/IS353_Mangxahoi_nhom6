# %% [markdown]
# # MOUNT DRIVE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/IS353 - Mạng xã hội - Nhóm 6/Đồ án môn học/Project/Model/KGAT-pytorch
# Out:
# /content/drive/MyDrive/IS353 - Mạng xã hội - Nhóm 6/Đồ án môn học/Project/Model/KGAT-pytorch

# %%
# !python main_bprmf.py \
        --data_dir "./" \
        --data_name KGAT_data \
        --use_pretrain 0 \
        --n_epoch 50 \
        --print_every 1000 \
        --evaluate_every 10 \
        --Ks '[1, 5, 10]'
# Out:
# All logs will be saved to trained_model/BPRMF/KGAT_data/embed-dim64_lr0.0001_pretrain0/log0.log
# 2024-12-09 00:58:59,777 - root - INFO - Namespace(seed=2019, data_name='KGAT_data', data_dir='./', use_pretrain=0, pretrain_embedding_dir='datasets/pretrain/', pretrain_model_path='trained_model/model.pth', embed_dim=64, l2loss_lambda=1e-05, train_batch_size=1024, test_batch_size=10000, lr=0.0001, n_epoch=50, stopping_steps=10, print_every=1000, evaluate_every=10, Ks='[1, 5, 10]', save_dir='trained_model/BPRMF/KGAT_data/embed-dim64_lr0.0001_pretrain0/')
# 2024-12-09 00:59:02,680 - root - INFO - n_users:     8273
# 2024-12-09 00:59:02,681 - root - INFO - n_items:     421
# 2024-12-09 00:59:02,681 - root - INFO - n_cf_train:  321407
# 2024-12-09 00:59:02,681 - root - INFO - n_cf_test:   8273
# 2024-12-09 00:59:02,748 - root - INFO - BPRMF(
#   (user_embed): Embedding(8273, 64)
#   (item_embed): Embedding(421, 64)
# )
# ...

# %%
# !python predict_bprmf.py \
        --data_dir "./" \
        --data_name KGAT_data \
        --use_pretrain 2 \
        --train_batch_size 1024 \
        --test_batch_size 1024 \
        --print_every 50 \
        --evaluate_every 5 \
        --Ks '[1, 5, 10]'\
        --pretrain_model_path '/content/drive/MyDrive/IS353 - Mạng xã hội - Nhóm 6/Đồ án môn học/Project/Model/KGAT-pytorch/trained_model/BPRMF/KGAT_data/embed-dim64_lr0.0001_pretrain0/model_epoch50.pth'
# Out:
# /content/drive/MyDrive/IS353 - Mạng xã hội - Nhóm 6/Đồ án môn học/Project/Model/KGAT-pytorch/utils/model_helper.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature
# ...
