# %% [markdown]
# # MOUNT DRIVE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/IS353 - Mạng xã hội - Nhóm 6/Đồ án môn học/Project/Model/KGAT-pytorch
# Out:
# /content/drive/MyDrive/IS353 - Mạng xã hội - Nhóm 6/Đồ án môn học/Project/Model/KGAT-pytorch

# %%
# !python main_kgat.py \
    --data_dir "./" \
    --data_name KGAT_data \
    --use_pretrain 0 \
    --n_epoch 50 \
    --cf_batch_size 1024 \
    --kg_batch_size 2048 \
    --test_batch_size 256 \
    --cf_print_every 500 \
    --kg_print_every 500 \
    --stopping_steps 5 \
    --evaluate_every 5 \
    --Ks '[1, 5, 10]'
# Out:
# All logs will be saved to trained_model/KGAT/KGAT_data/embed-dim64_relation-dim64_random-walk_bi-interaction_64-32-16_lr0.0001_pretrain0/log0.log
# 2024-12-09 02:03:45,250 - root - INFO - Namespace(seed=2019, data_name='KGAT_data', data_dir='./', use_pretrain=0, pretrain_embedding_dir='datasets/pretrain/', pretrain_model_path='trained_model/model.pth', cf_batch_size=1024, kg_batch_size=2048, test_batch_size=256, embed_dim=64, relation_dim=64, laplacian_type='random-walk', aggregation_type='bi-interaction', conv_dim_list='[64, 32, 16]', mess_dropout='[0.1, 0.1, 0.1]', kg_l2loss_lambda=1e-05, cf_l2loss_lambda=1e-05, lr=0.0001, n_epoch=50, stopping_steps=5, cf_print_every=500, kg_print_every=500, evaluate_every=5, Ks='[1, 5, 10]', predict_embed=0, save_dir='trained_model/KGAT/KGAT_data/embed-dim64_relation-dim64_random-walk_bi-interaction_64-32-16_lr0.0001_pretrain0/')
# 2024-12-09 02:04:26,175 - root - INFO - n_users:           8273
# ...

# %%
  # !python predict_kgat.py  --data_dir "./" \
                    --data_name KGAT_data \
                    --use_pretrain 2 \
                    --n_epoch 50 \
                    --cf_batch_size 1024 \
                    --kg_batch_size 2048 \
                    --test_batch_size 256 \
                    --cf_print_every 50 \
                    --kg_print_every 50 \
                    --evaluate_every 5 \
                    --Ks '[1, 5, 10]'\
                    --pretrain_model_path "/content/drive/MyDrive/IS353 - Mạng xã hội - Nhóm 6/Đồ án môn học/Project/Model/KGAT-pytorch/trained_model/KGAT/KGAT_data/embed-dim64_relation-dim64_random-walk_bi-interaction_64-32-16_lr0.0001_pretrain0/model_epoch35.pth"
# Out:
# Evaluating Iteration: 100% 33/33 [00:06<00:00,  5.05it/s]
# trained_model/KGAT/KGAT_data/embed-dim64_relation-dim64_random-walk_bi-interaction_64-32-16_lr0.0001_pretrain2/cf_scores.npy
# *** CF Evaluation @1 ***
# Precision@1   :  0.15737943
# Recall@1      :  0.15737943
# NDCG@1        :  0.15737942705185543
# *** CF Evaluation @5 ***
# Precision@5   :  0.07487006
# Recall@5      :  0.3743503
# NDCG@5        :  0.27134185957929263
# *** CF Evaluation @10 ***
# Precision@10   :  0.046065524
# Recall@10      :  0.46065515
# NDCG@10        :  0.2994672028449816
