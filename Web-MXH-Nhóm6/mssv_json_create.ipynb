# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import json

# %%
unrecommend = pd.read_excel('Data/Test_recommend/unrecommend_data.xlsx')

# %%
recommend = pd.read_excel('Data/Test_recommend/recommend_data.xlsx')

# %%
mssv1 = '21521804'
mssv2 = '21521323'

# %%
create_json = [
    {
        "mssv": mssv1,
        "mssv_raw": recommend['mssv'].unique()[0],
    },
    {
        "mssv": mssv2,
        "mssv_raw": unrecommend['mssv'].unique()[0],
    }
]

# %%
# Save the list as a JSON file
with open('mssv.json', 'w') as f:
    json.dump(create_json, f, indent=4)
